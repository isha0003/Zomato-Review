# %%
import pandas as pd

# %%
df=pd.read_csv("/Users/ishashree/Downloads/zomato.csv" ,encoding = 'latin-1')
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
# !pip install openpyxl

# %%
df_1=pd.read_excel("/Users/ishashree/Downloads/Country-Code.xlsx")
df_1
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df_final=pd.merge(df,df_1, on="Country Code",how="right")
df_final
# Out:
#       Restaurant ID                           Restaurant Name  Country Code  \
# 0           3400025                                Jahanpanah             1
# 1           3400341                       Rangrezz Restaurant             1
# 2           3400005                   Time2Eat - Mama Chicken             1
# 3           3400021     Chokho Jeeman Marwari Jain Bhojanalya             1
# 4           3400017                            Pinch Of Spice             1
# ...             ...                                       ...           ...
# 9546       17697389                       The Screaming Eagle           216
# 9547       17697424                             The Thai Bowl           216
# 9548       17697332                Tokyo Japanese Steak House           216
# 9549       17694056  Theo Yianni's Authentic Greek Restaurant           216
# 9550       17559793                 Fishpatrick's Crabby Cafe           216
#
# ...

# %%
df_final.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df_x=df_final[['Country','City','Currency','Average Cost for two','Has Table booking','Has Online delivery','Aggregate rating','Rating color','Rating text','Votes']]
df_x
# Out:
#             Country            City            Currency  Average Cost for two  \
# 0             India            Agra  Indian Rupees(Rs.)                   850
# 1             India            Agra  Indian Rupees(Rs.)                   700
# 2             India            Agra  Indian Rupees(Rs.)                   500
# 3             India            Agra  Indian Rupees(Rs.)                   400
# 4             India            Agra  Indian Rupees(Rs.)                  1000
# ...             ...             ...                 ...                   ...
# 9546  United States        Waterloo           Dollar($)                    10
# 9547  United States        Waterloo           Dollar($)                    10
# 9548  United States        Waterloo           Dollar($)                    25
# 9549  United States         Weirton           Dollar($)                    25
# 9550  United States  Winchester Bay           Dollar($)                    25
#
# ...

# %%
df_x.Country.value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
df_x.isnull().sum()
# Out:
# Country                 0
# City                    0
# Currency                0
# Average Cost for two    0
# Has Table booking       0
# Has Online delivery     0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn

# %%
plt.figure(figsize=(40,10))
sn.countplot(x="Country",data=df_x)
plt.x_label="Country"
plt.y_label="order"

# %% [markdown]
# India has the largest number of order
# USA comes second and UK is third

# %%
df_ind=df_x[df_x["Country"]=="India"]
df_ind
# Out:
#      Country   City            Currency  Average Cost for two  \
# 0      India   Agra  Indian Rupees(Rs.)                   850
# 1      India   Agra  Indian Rupees(Rs.)                   700
# 2      India   Agra  Indian Rupees(Rs.)                   500
# 3      India   Agra  Indian Rupees(Rs.)                   400
# 4      India   Agra  Indian Rupees(Rs.)                  1000
# ...      ...    ...                 ...                   ...
# 8647   India  Vizag  Indian Rupees(Rs.)                   600
# 8648   India  Vizag  Indian Rupees(Rs.)                   400
# 8649   India  Vizag  Indian Rupees(Rs.)                   600
# 8650   India  Vizag  Indian Rupees(Rs.)                  1500
# 8651   India  Vizag  Indian Rupees(Rs.)                  1400
#
#      Has Table booking Has Online delivery  Aggregate rating Rating color  \
# 0                   No                  No               3.9       Yellow
# ...

# %%
city=df_ind["City"].value_counts()
city
# Out:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Guwahati          21
# Lucknow           21
# Bhubaneshwar      21
# Amritsar          21
# Pune              20
# Puducherry        20
# Patna             20
# Ludhiana          20
# Ranchi            20
# Surat             20
# Vadodara          20
# Nashik            20
# Nagpur            20
# Mysore            20
# Mumbai            20
# Varanasi          20
# Mangalore         20
# Agra              20
# Kochi             20
# Kolkata           20
# Dehradun          20
# Allahabad         20
# Aurangabad        20
# Bangalore         20
# Bhopal            20
# Chennai           20
# Coimbatore        20
# Goa               20
# Indore            20
# Jaipur            20
# Kanpur            20
# Vizag             20
# Chandigarh        18
# Hyderabad         18
# Secunderabad       2
# Panchkula          1
# Mohali             1
# ...

# %%
plt.figure(figsize = (19,9))
#plt.xlabel="City"
#plt.ylabel="Order Count"
city[:5].plot(kind = 'bar', color = ['r','m','g','b','y'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# New Delhi has the max amount or orders
# Gurgaon comes second followed by Noida

# %%
df_usa=df_x[df_x["Country"]=="United States"]
df_usa
# Out:
#             Country            City   Currency  Average Cost for two  \
# 9117  United States          Albany  Dollar($)                    25
# 9118  United States          Albany  Dollar($)                    10
# 9119  United States          Albany  Dollar($)                     0
# 9120  United States          Albany  Dollar($)                     0
# 9121  United States          Albany  Dollar($)                    10
# ...             ...             ...        ...                   ...
# 9546  United States        Waterloo  Dollar($)                    10
# 9547  United States        Waterloo  Dollar($)                    10
# 9548  United States        Waterloo  Dollar($)                    25
# 9549  United States         Weirton  Dollar($)                    25
# 9550  United States  Winchester Bay  Dollar($)                    25
#
#      Has Table booking Has Online delivery  Aggregate rating Rating color  \
# ...

# %%
city_usa=df_usa.City.value_counts()
city_usa
# Out:
# Albany                    20
# Gainesville               20
# Pensacola                 20
# Orlando                   20
# Rest of Hawaii            20
# Savannah                  20
# Sioux City                20
# Athens                    20
# Macon                     20
# Tampa Bay                 20
# Valdosta                  20
# Pocatello                 20
# Dubuque                   20
# Des Moines                20
# Davenport                 20
# Dalton                    20
# Columbus                  20
# Waterloo                  20
# Cedar Rapids/Iowa City    20
# Boise                     20
# Augusta                   20
# Princeton                  1
# Weirton                    1
# Vernonia                   1
# Mc Millan                  1
# Potrero                    1
# Ojo Caliente               1
# Monroe                     1
# Miller                     1
# Lincoln                    1
# Lakeview                   1
# Fernley                    1
# ...

# %%
city_usa[:21].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
city_usa[:5].plot(kind="bar",color=['r','m','g','b','y'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# Albany,Gainesv,Pensaco,Orlando,Rest of Hawaii,Savanna,Sioux,Athens,Macon,Tampa Bay,Valdosta,Pocatello,Dubuque,Des Moine,Davenport,Dalton,Columbus,Waterloo,Cedar Rap,Boise,Augusta have same no.of orders

# %%
df_uk=df_x[df_x["Country"]=="United Kingdom"]
df_uk
# Out:
#              Country        City    Currency  Average Cost for two  \
# 9037  United Kingdom  Birmingham  Pounds(£)                    10
# 9038  United Kingdom  Birmingham  Pounds(£)                    15
# 9039  United Kingdom  Birmingham  Pounds(£)                    60
# 9040  United Kingdom  Birmingham  Pounds(£)                    30
# 9041  United Kingdom  Birmingham  Pounds(£)                    35
# ...              ...         ...         ...                   ...
# 9112  United Kingdom  Manchester  Pounds(£)                    80
# 9113  United Kingdom  Manchester  Pounds(£)                    30
# 9114  United Kingdom  Manchester  Pounds(£)                    25
# 9115  United Kingdom  Manchester  Pounds(£)                    55
# 9116  United Kingdom  Manchester  Pounds(£)                   160
#
#      Has Table booking Has Online delivery  Aggregate rating Rating color  \
# 9037                No                  No               2.8       Orange
# ...

# %%
city_uk=df_uk.City.value_counts()
city_uk
# Out:
# Birmingham    20
# Edinburgh     20
# London        20
# Manchester    20
# Name: City, dtype: int64

# %%
plt.figure(figsize = (19,9))
city_uk.plot(kind = 'bar', color = ['r','m','g','b'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# =>All city has same order number
# =>It is possible that our dataset does not contain all order data

# %%
df_avg_cost=df_x["Average Cost for two"].value_counts()
df_avg_cost[:10]
# Out:
# 500    900
# 300    897
# 400    857
# 200    687
# 600    652
# 250    461
# 350    457
# 700    403
# 150    367
# 100    353
# Name: Average Cost for two, dtype: int64

# %%
df_avg_cost[:10].plot(kind="bar",color=["r","m","g","b","y"])
plt.xlabel('Order Price')
plt.ylabel('Order Quantity')
# Out:
# Text(0, 0.5, 'Order Quantity')

# %%
df_online_delivery=df_x[df_x["Has Online delivery"]=="Yes"].groupby('Country').size().reset_index()
df_online_delivery
# Out:
#   Country     0
# 0   India  2423
# 1     UAE    28

# %% [markdown]
# Only two countries allow online delivery(India and UAE)

# %%
df_table_book=df_x[df_x["Has Table booking"]=="Yes"].groupby('Country').size().reset_index()
df_table_book
# Out:
#           Country     0
# 0           India  1111
# 1     Phillipines    14
# 2           Qatar     1
# 3    South Africa     2
# 4             UAE    18
# 5  United Kingdom    12

# %% [markdown]
# Table booking is available the most in India followed by UAE but the frequency is less

# %%
df_rating=df_x.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:"Rating Count"})
df_rating
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
plt.figure(figsize = (19,9))
sn.barplot(df_rating["Aggregate rating"],df_rating["Rating Count"])
# Out:
# /Users/ishashree/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
plt.figure(figsize = (19,9))
sn.countplot(df_rating["Rating text"])
# Out:
# /Users/ishashree/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rating text', ylabel='count'>
